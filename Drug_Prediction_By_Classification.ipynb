# %% [markdown]
# **Import Library**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Import Data**

# %%
df = pd.read_csv('drug200.csv')
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.nunique()
# Out:
# Age             57
# Sex              2
# BP               3
# Cholesterol      2
# Na_to_K        198
# Drug             5
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                Age  Sex    BP Cholesterol     Na_to_K   Drug
# count   200.000000  200   200         200  200.000000    200
# unique         NaN    2     3           2         NaN      5
# top            NaN    M  HIGH        HIGH         NaN  DrugY
# freq           NaN  104    77         103         NaN     91
# mean     44.315000  NaN   NaN         NaN   16.084485    NaN
# std      16.544315  NaN   NaN         NaN    7.223956    NaN
# min      15.000000  NaN   NaN         NaN    6.269000    NaN
# 25%      31.000000  NaN   NaN         NaN   10.445500    NaN
# 50%      45.000000  NaN   NaN         NaN   13.936500    NaN
# 75%      58.000000  NaN   NaN         NaN   19.380000    NaN
# max      74.000000  NaN   NaN         NaN   38.247000    NaN

# %%
for i in df.columns:
  print(df[i].value_counts())
  print('--'*50)
# Out:
# 47    8
# 23    7
# 28    7
# 49    7
# 39    6
# 32    6
# 50    5
# 37    5
# 58    5
# 60    5
# 22    5
# 34    4
# 72    4
# 51    4
# 42    4
# 26    4
# 24    4
# 74    4
# 67    4
# 68    4
# 61    4
# 56    4
# 20    4
# 36    4
# 45    4
# 41    4
# 31    4
# 43    4
# 65    4
# 57    4
# 53    3
# 40    3
# 70    3
# 59    3
# 16    3
# 38    3
# 15    3
# 69    3
# 35    3
# 18    3
# 64    3
# 52    2
# 55    2
# 62    2
# 19    2
# 29    2
# 66    2
# 73    2
# 46    2
# 48    2
# 54    1
# 17    1
# 33    1
# 63    1
# 30    1
# 21    1
# 25    1
# Name: Age, dtype: int64
# ----------------------------------------------------------------------------------------------------
# M    104
# F     96
# Name: Sex, dtype: int64
# ----------------------------------------------------------------------------------------------------
# HIGH      77
# LOW       64
# NORMAL    59
# Name: BP, dtype: int64
# ----------------------------------------------------------------------------------------------------
# HIGH      103
# NORMAL     97
# Name: Cholesterol, dtype: int64
# ----------------------------------------------------------------------------------------------------
# 12.006    2
# 18.295    2
# 25.355    1
# 11.939    1
# 16.347    1
#          ..
# 24.658    1
# 24.276    1
# 13.967    1
# 19.675    1
# 11.349    1
# Name: Na_to_K, Length: 198, dtype: int64
# ----------------------------------------------------------------------------------------------------
# DrugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Data Visualization**

# %%
df.Drug.value_counts().plot(kind='bar')
plt.show()

# %%
df.BP.value_counts().plot(kind='bar')
plt.show()

# %%
df.Sex.value_counts().plot(kind='bar')
plt.show()

# %%
group_with_age = df.groupby('Drug')['Age'].mean().plot(kind='bar')
plt.title('Drug Respected with Age')
plt.ylabel('Age')
plt.show()

# %%
sns.countplot(x='Sex',hue='Drug',data=df)
plt.show()

# %%
sns.countplot(x='BP',hue='Drug',data=df)
plt.show()

# %%
sns.countplot(x='Cholesterol',hue='Drug',data=df)
plt.show()

# %%
sns.boxplot(x='Sex',y='Age',hue='Drug',data=df)
plt.show()

# %%
sns.histplot(x='Age',hue='Drug',bins=10,kde=True,data=df)
plt.show()

# %%
sns.histplot(x='Age',hue='Cholesterol',bins=10,kde=True,data=df)
plt.show()

# %%
sns.histplot(x='Age',hue='BP',bins=10,kde=True,data=df)
plt.show()

# %%
sns.histplot(x='Na_to_K',hue='BP',bins=10,kde=True,data=df)
plt.show()

# %%
sns.histplot(x='Na_to_K',hue='Drug',bins=10,kde=True,data=df)
plt.show()

# %% [markdown]
# **Finding Correlation**

# %%
sns.heatmap(df.corr(),robust=True,annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# **Convert Categorical Data into Numeric Data**

# %%
from sklearn.preprocessing import LabelEncoder
for i in ['Sex', 'BP','Cholesterol','Drug']:
  df[i] = LabelEncoder().fit_transform(df[i])

# %%
cor = df.corr().abs()
cor['Drug'].sort_values(ascending=False).plot(kind='bar')
plt.title('Range of Correlation With Drugs')
plt.show()

# %% [markdown]
# **1.Without Feature Scaling And Featue Selection**

# %% [markdown]
# **Convert Data into Target and Independent Variables**

# %%
X = df.drop('Drug',axis=1)
y = df['Drug']

# %% [markdown]
# **Spliting Data into train and test dataset for model**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=123)

# %% [markdown]
# **Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train,y_train)
print('Test Score =>',model.score(X_test,y_test))
print('Training Score =>',model.score(X_train,y_train))
y_pred_lr = model.predict(X_test)
y_pred_lr = y_pred_lr.astype('int')
print('Classification Report')
print(classification_report(y_test,y_pred_lr))
# Out:
# Test Score => 0.5178267508408532
# Training Score => 0.6017727498364694
# Classification Report
#               precision    recall  f1-score   support
#
#           -2       0.00      0.00      0.00         0
#           -1       0.00      0.00      0.00         0
#            0       0.92      0.52      0.67        23
#            1       0.17      0.50      0.25         2
#            2       0.07      0.33      0.12         3
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.35        40
#    macro avg       0.17      0.19      0.15        40
# weighted avg       0.54      0.35      0.40        40

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression().fit(X_train,y_train)
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print('Accuracy Score of Logistic Model=>',accuracy_score(y_test,model1.predict(X_test)))
print('Classification Report of Logistic Model=>\n',classification_report(y_test,model1.predict(X_test)))
print('Confusion Matrix : ')
sns.heatmap(confusion_matrix(y_test,model1.predict(X_test)),annot=True,fmt='.2f')
plt.show()
# Out:
# Accuracy Score of Logistic Model=> 0.825
# Classification Report of Logistic Model=>
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        23
#            1       0.50      0.50      0.50         2
#            2       0.67      0.67      0.67         3
#            3       1.00      0.33      0.50         3
#            4       0.67      0.89      0.76         9
#
#     accuracy                           0.82        40
#    macro avg       0.76      0.66      0.67        40
# weighted avg       0.85      0.82      0.82        40
#
# Confusion Matrix :

# %% [markdown]
# **2.Only With High Correled Feature**

# %%
X2 = df.drop(columns=['Cholesterol','Age','Sex','Drug'])
y2 = df['Drug']
X_train1,X_test1,y_train1,y_test1 = train_test_split(X2,y2,train_size=0.8,test_size=0.2,random_state=123)

# %% [markdown]
# **Linear Regression**

# %%
model01 = LinearRegression().fit(X_train1,y_train1)
print(model01.score(X_test1,y_test1))
y_pred_lr = model01.predict(X_test1)
y_pred_lr = y_pred_lr.astype('int')
print(classification_report(y_test1,y_pred_lr))
# Out:
# 0.538996592304397
#               precision    recall  f1-score   support
#
#           -2       0.00      0.00      0.00         0
#           -1       0.00      0.00      0.00         0
#            0       1.00      0.61      0.76        23
#            1       0.12      0.50      0.20         2
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.38        40
#    macro avg       0.16      0.16      0.14        40
# weighted avg       0.58      0.38      0.45        40

# %% [markdown]
# **Logistic Regression**

# %%
model02 = LogisticRegression().fit(X_train1,y_train1)
print('Accuracy Score of Logistic Model=>',accuracy_score(y_test1,model02.predict(X_test1)))
print('Classification Report of Logistic Model=>\n',classification_report(y_test1,model02.predict(X_test1)))
print('Confusion Matrix : ')
sns.heatmap(confusion_matrix(y_test1,model02.predict(X_test1)),annot=True,fmt='.2f')
plt.show()
# Out:
# Accuracy Score of Logistic Model=> 0.85
# Classification Report of Logistic Model=>
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       0.40      1.00      0.57         2
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00         3
#            4       0.75      1.00      0.86         9
#
#     accuracy                           0.85        40
#    macro avg       0.43      0.60      0.49        40
# weighted avg       0.76      0.85      0.80        40
#
# Confusion Matrix :

# %% [markdown]
# **Feature Salection**

# %%
from sklearn.feature_selection import VarianceThreshold
var = VarianceThreshold().fit_transform(X_train)
var.shape
# Out:
# (160, 5)

# %%
var = pd.DataFrame(var)

# %%
var.rename(columns={0:'Age',1:'Sex',2:'BP',3:'Cholesterol',4:'Na_to_K'},inplace=True)

# %% [markdown]
# **Linear Regression**

# %%
model_lr = LinearRegression().fit(var,y_train)
accuracy_score(y_test,(model_lr.predict(X_test).astype('int')))
# Out:
# 0.35

# %% [markdown]
# **Logistic Regression**

# %%
model0 = LogisticRegression().fit(var,y_train)
accuracy_score(y_test,model0.predict(X_test))
# Out:
# 0.825

# %% [markdown]
# **With Feature Scaling**

# %% [markdown]
# **Standardiation**

# %%
with_std = df.copy()

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
with_std['Na_to_K'] = StandardScaler().fit_transform(with_std['Na_to_K'].values.reshape(-1,1))
X3 = with_std.drop('Drug',axis=1)
y3 = with_std['Drug']
X_train2,X_test2,y_train2,y_test2 = train_test_split(X3,y3,train_size=0.8,test_size=0.2,random_state=123)

# %% [markdown]
# **Linear Regression**

# %%
model_std = LinearRegression().fit(X_train2,y_train2)
print(model_std.score(X_test2,y_test2))
y_pred_lr = model_std.predict(X_test2)
y_pred_lr = y_pred_lr.astype('int')
print(classification_report(y_test2,y_pred_lr))
# Out:
# 0.5178267508408504
#               precision    recall  f1-score   support
#
#           -2       0.00      0.00      0.00         0
#           -1       0.00      0.00      0.00         0
#            0       0.92      0.52      0.67        23
#            1       0.17      0.50      0.25         2
#            2       0.07      0.33      0.12         3
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.35        40
#    macro avg       0.17      0.19      0.15        40
# weighted avg       0.54      0.35      0.40        40

# %% [markdown]
# **Logistic Regression**

# %%
model_std1 = LogisticRegression().fit(X_train2,y_train2)
print('Accuracy Score of Logistic Model=>',accuracy_score(y_test2,model_std1.predict(X_test2)))
print('Classification Report of Logistic Model=>\n',classification_report(y_test2,model_std1.predict(X_test2)))
print('Confusion Matrix : ')
sns.heatmap(confusion_matrix(y_test2,model_std1.predict(X_test2)),annot=True,fmt='.2f')
plt.show()
# Out:
# Accuracy Score of Logistic Model=> 1.0
# Classification Report of Logistic Model=>
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         9
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# Confusion Matrix :

# %% [markdown]
# **Normalization**

# %%
with_min = df.copy()

# %%
with_min['Na_to_K'] = MinMaxScaler().fit_transform(with_min['Na_to_K'].values.reshape(-1,1))
X4 = with_min.drop('Drug',axis=1)
y4 = with_min['Drug']
X_train3,X_test3,y_train3,y_test3 = train_test_split(X4,y4,train_size=0.8,test_size=0.2,random_state=123)

# %% [markdown]
# **Linear Regression**

# %%
model_min = LinearRegression().fit(X_train3,y_train3)
print(model_min.score(X_test3,y_test3))
y_pred_lr = model_min.predict(X_test3)
y_pred_lr = y_pred_lr.astype('int')
print(classification_report(y_test3,y_pred_lr))
# Out:
# 0.517826750840853
#               precision    recall  f1-score   support
#
#           -2       0.00      0.00      0.00         0
#           -1       0.00      0.00      0.00         0
#            0       0.92      0.52      0.67        23
#            1       0.17      0.50      0.25         2
#            2       0.07      0.33      0.12         3
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.35        40
#    macro avg       0.17      0.19      0.15        40
# weighted avg       0.54      0.35      0.40        40

# %% [markdown]
# **Logistic Regression**

# %%
model_min1 = LogisticRegression().fit(X_train3,y_train3)
print('Accuracy Score of Logistic Model=>',accuracy_score(y_test3,model_min1.predict(X_test3)))
print('Classification Report of Logistic Model=>\n',classification_report(y_test3,model_min1.predict(X_test3)))
print('Confusion Matrix : ')
sns.heatmap(confusion_matrix(y_test3,model_min1.predict(X_test3)),annot=True,fmt='.2f')
plt.show()
# Out:
# Accuracy Score of Logistic Model=> 0.85
# Classification Report of Logistic Model=>
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        23
#            1       0.67      1.00      0.80         2
#            2       1.00      1.00      1.00         3
#            3       1.00      0.33      0.50         3
#            4       0.80      0.89      0.84         9
#
#     accuracy                           0.85        40
#    macro avg       0.87      0.82      0.80        40
# weighted avg       0.86      0.85      0.84        40
#
# Confusion Matrix :

# %% [markdown]
# **Cross Validation**

# %%
from sklearn.model_selection import cross_val_score
print('Linear Model WithOut Feature Scalling and Selection=>',cross_val_score(model,X_train,y_train,cv=10))
print('__'*50)
print('Logistic Model WithOut Feature Scalling and Selection=>',cross_val_score(model1,X_train,y_train,cv=10))
print('__'*50)
print('Linear Model Only With High Correled Feature=>',cross_val_score(model01,X_train1,y_train1,cv=10))
print('__'*50)
print('Logistic Model Only With High Correled Feature=>',cross_val_score(model02,X_train1,y_train1,cv=10))
print('__'*50)
print('Linear Model With Feature Salection=>',cross_val_score(model_lr,X_train,y_train,cv=10))
print('__'*50)
print('Logistic Model With Feature Salection=>',cross_val_score(model0,X_train,y_train,cv=10))
print('__'*50)
print('Linear Model With Featue Scalling with Standardiation=>',cross_val_score(model_std,X_train2,y_train2,cv=10))
print('__'*50)
print('Logistic Model With Featue Scalling with Standardiation=>',cross_val_score(model_std1,X_train2,y_train2,cv=10))
print('__'*50)
print('Linear Model With Featue Scalling with Normalization=>',cross_val_score(model_min,X_train3,y_train3,cv=10))
print('__'*50)
print('Logistic Model With Featue Scalling with Normalization=>',cross_val_score(model_min1,X_train3,y_train3,cv=10))
print('__'*50)
# Out:
# Linear Model WithOut Feature Scalling and Selection=> [0.33860401 0.50789376 0.55193305 0.75443371 0.59330079 0.6221947
#  0.73301705 0.5699451  0.62445255 0.21833124]
# ____________________________________________________________________________________________________
# Logistic Model WithOut Feature Scalling and Selection=> [0.75   0.875  0.9375 0.9375 0.75   0.8125 0.9375 0.875  0.875  0.8125]
# ____________________________________________________________________________________________________
# Linear Model Only With High Correled Feature=> [0.26242901 0.50359532 0.49036342 0.74019914 0.57995863 0.68957646
#  0.7280651  0.60432579 0.61560546 0.2372577 ]
# ____________________________________________________________________________________________________
# Logistic Model Only With High Correled Feature=> [0.875  0.8125 0.875  0.875  0.8125 0.8125 0.8125 0.8125 0.75   0.75  ]
# ____________________________________________________________________________________________________
# Linear Model With Feature Salection=> [0.33860401 0.50789376 0.55193305 0.75443371 0.59330079 0.6221947
#  0.73301705 0.5699451  0.62445255 0.21833124]
# ____________________________________________________________________________________________________
# Logistic Model With Feature Salection=> [0.75   0.875  0.9375 0.9375 0.75   0.8125 0.9375 0.875  0.875  0.8125]
# ____________________________________________________________________________________________________
# Linear Model With Featue Scalling with Standardiation=> [0.33860401 0.50789376 0.55193305 0.75443371 0.59330079 0.6221947
#  0.73301705 0.5699451  0.62445255 0.21833124]
# ____________________________________________________________________________________________________
# Logistic Model With Featue Scalling with Standardiation=> [0.9375 0.9375 0.875  0.9375 0.875  0.8125 0.875  0.875  0.9375 0.9375]
# ____________________________________________________________________________________________________
# Linear Model With Featue Scalling with Normalization=> [0.33860401 0.50789376 0.55193305 0.75443371 0.59330079 0.6221947
#  0.73301705 0.5699451  0.62445255 0.21833124]
# ____________________________________________________________________________________________________
# Logistic Model With Featue Scalling with Normalization=> [0.8125 0.8125 0.9375 0.875  0.875  0.9375 0.875  0.75   0.75   0.8125]
# ____________________________________________________________________________________________________

# %% [markdown]
# **Conclusion**

# %% [markdown]
# **WithOut Feature Scalling and Selection**
#
# Acuuracy:
#   1. Linear Regression = 0.5178267508408532
#   2. Logistic Regression = 0.825
#
# **Only With High Correled Feature**
#
# Acuuracy:
#   1. Linear Regression = 0.35
#   2. Logistic Regression = 1.0
#
# **With Feature Salection**
#
# Acuuracy:
#   1. Linear Regression = 0.35
#   2. Logistic Regression = 1.0
#
# **With Featue Scalling**<br>
# 1.Standardiation<br>
# Accuracy:
#   1. Linear Regression = 0.5178267508408505
#   2. Logistic Regression =  1.0
#
# 2.Normalization<br>
# Acuuracy:
#   1. Linear Regression = 0.517826750840853
#   2. Logistic Regression = 0.85

# %% [markdown]
# **1.What is Feature Scaling?**<br>
# Feature scaling is a method used to normalize the range of independent variables or features of data. In data processing, it is also known as data normalization and is generally performed during the data preprocessing step. Just to give you an example — if you have multiple independent variables like age, salary, and height; With their range as (18–100 Years), (25,000–75,000 Euros), and (1–2 Meters) respectively, feature scaling would help them all to be in the same range, for example- centered around 0 or in the range (0,1) depending on the scaling technique.
#
# In order to visualize the above, let us take an example of the independent variables of alcohol and Malic Acid content in the wine dataset from the “Wine Dataset” that is deposited on the UCI machine learning repository. Below you can see the impact of the two most common scaling techniques (Normalization and Standardization) on the dataset.<br>
# ![1_eFwb_Vy-QgXqln6Y6GGrHw-2.png](data:image/png;base64,...)

# %% [markdown]
# **Methods for Scaling**
#
# Now, since you have an idea of what is feature scaling. Let us explore what methods are available for doing feature scaling. Of all the methods available, the most common ones are:
#
# **Normalization**<br>
# Also known as min-max scaling or min-max normalization, it is the simplest method and consists of rescaling the range of features to scale the range in [0, 1]. The general formula for normalization is given as:
#
#
# Here, max(x) and min(x) are the maximum and the minimum values of the feature respectively.
#
# We can also do a normalization over different intervals, e.g. choosing to have the variable laying in any [a, b] interval, a and b being real numbers. To rescale a range between an arbitrary set of values [a, b], the formula becomes:
#
#
# **Standardization**
#
# Feature standardization makes the values of each feature in the data have zero mean and unit variance. The general method of calculation is to determine the distribution mean and standard deviation for each feature and calculate the new data point by the following formula:
#
#
# Here, σ is the standard deviation of the feature vector, and x̄ is the average of the feature vector.
#
# **Scaling to unit length**<br>
# The aim of this method is to scale the components of a feature vector such that the complete vector has length one. This usually means dividing each component by the Euclidean length of the vector:
#
#
# In addition to the above 3 widely-used methods, there are some other methods to scale the features viz. Power Transformer, Quantile Transformer, Robust Scaler, etc. For the scope of this discussion, we are deliberately not diving into the details of these techniques.
#
# The million-dollar question: Normalization or Standardization
# If you have ever built a machine learning pipeline, you must have always faced this question of whether to Normalize or to Standardize. While there is no obvious answer to this question, it really depends on the application, there are still a few generalizations that can be drawn.
#
# Normalization is good to use when the distribution of data does not follow a Gaussian distribution. It can be useful in algorithms that do not assume any distribution of the data like K-Nearest Neighbors.
#
# In Neural Networks algorithm that require data on a 0–1 scale, normalization is an essential pre-processing step. Another popular example of data normalization is image processing, where pixel intensities have to be normalized to fit within a certain range (i.e., 0 to 255 for the RGB color range).
#
# Standardization can be helpful in cases where the data follows a Gaussian distribution. Though this does not have to be necessarily true. Since standardization does not have a bounding range, so, even if there are outliers in the data, they will not be affected by standardization.
#
# In clustering analyses, standardization comes in handy to compare similarities between features based on certain distance measures. Another prominent example is the Principal Component Analysis, where we usually prefer standardization over Min-Max scaling since we are interested in the components that maximize the variance.
#
# There are some points which can be considered while deciding whether we need Standardization or Normalization
#
# Standardization may be used when data represent Gaussian Distribution, while Normalization is great with Non-Gaussian Distribution
# Impact of Outliers is very high in Normalization
#
# To conclude, you can always start by fitting your model to raw, normalized, and standardized data and compare the performance for the best results.

# %% [markdown]
# **2.Feature Selection and Dimensionality Reduction**

# %% [markdown]
# **Feature Selection vs Dimensionality Reduction**<br>
# Often, feature selection and dimensionality reduction are grouped together (like here in this article). While both methods are used for reducing the number of features in a dataset, there is an important difference.
#
# Feature selection is simply selecting and excluding given features without changing them.
#
# Dimensionality reduction transforms features into a lower dimension.
#
# we will explore the following feature selection and dimensionality reduction techniques:
#
# **Feature Selection**
# Remove features with missing values<br>
# Remove features with low variance<br>
# Remove highly correlated features<br>
# Univariate feature selection<br>
# Recursive feature elimination<br>
# Feature selection using SelectFromModel<br>
# **Dimensionality Reduction**<br>
# PCA
